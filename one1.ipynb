# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
xls1 = pd.read_excel("data/2013_manhattan.xls")
xls2 = pd.read_excel("data/2014_manhattan.xls")
xls3 = pd.read_excel("data/2015_manhattan.xls")
xls4 = pd.read_excel("data/2016_manhattan.xls")
xls5 = pd.read_excel("data/2017_manhattan.xls")

df1 = pd.DataFrame(xls1)
df2 = pd.DataFrame(xls2)
df3 = pd.DataFrame(xls3)
df4 = pd.DataFrame(xls4)
df5 = pd.DataFrame(xls5)

# %%
df = [df1,df2,df3,df4,df5]

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26715 entries, 0 to 26714
# Data columns (total 22 columns):
# BOROUGH
#                            26715 non-null int64
# NEIGHBORHOOD
#                       26715 non-null object
# BUILDING CLASS CATEGORY
#            26715 non-null object
# TAX CLASS AT PRESENT
#               26715 non-null object
# BLOCK
#                              26715 non-null int64
# LOT
#                                26715 non-null int64
# EASE-MENT
#                          26715 non-null object
# BUILDING CLASS AT PRESENT
#          26715 non-null object
# ADDRESS
#                            26715 non-null object
# APARTMENT NUMBER
#                   26715 non-null object
# ZIP CODE
#                           26715 non-null int64
# RESIDENTIAL UNITS
#                  26715 non-null int64
# COMMERCIAL UNITS
#                   26715 non-null int64
# TOTAL UNITS
#                        26715 non-null int64
# LAND SQUARE FEET
# ...

# %%
for i in df:
    i.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26715 entries, 0 to 26714
# Data columns (total 21 columns):
# BOROUGH
#                            26715 non-null int64
# NEIGHBORHOOD
#                       26715 non-null object
# BUILDING CLASS CATEGORY
#            26715 non-null object
# TAX CLASS AT PRESENT
#               26715 non-null object
# BLOCK
#                              26715 non-null int64
# LOT
#                                26715 non-null int64
# EASE-MENT
#                          26715 non-null object
# BUILDING CLASS AT PRESENT
#          26715 non-null object
# ADDRESS
#                            26715 non-null object
# APARTMENT NUMBER
#                   26715 non-null object
# ZIP CODE
#                           26715 non-null int64
# RESIDENTIAL UNITS
#                  26715 non-null int64
# COMMERCIAL UNITS
#                   26715 non-null int64
# TOTAL UNITS
#                        26715 non-null int64
# LAND SQUARE FEET
# ...

# %%
df5.describe(include='all').T
# Out:
#                                        count unique  \
# BOROUGH\n                              18642    NaN
# NEIGHBORHOOD\n                         18642     39
# BUILDING CLASS CATEGORY\n              18642     43
# TAX CLASS AS OF FINAL ROLL 17/18       18642      9
# BLOCK\n                                18642    NaN
# LOT\n                                  18642    NaN
# EASE-MENT\n                            18642      1
# BUILDING CLASS AS OF FINAL ROLL 17/18  18642    125
# ADDRESS\n                              18642  11617
# APARTMENT NUMBER\n                     18642   2461
# ZIP CODE\n                             18642    NaN
# RESIDENTIAL UNITS\n                    18642    NaN
# COMMERCIAL UNITS\n                     18642    NaN
# TOTAL UNITS\n                          18642    NaN
# LAND SQUARE FEET\n                     18642    NaN
# GROSS SQUARE FEET\n                    18642    NaN
# YEAR BUILT\n                           18642    NaN
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26715 entries, 0 to 26714
# Data columns (total 21 columns):
# BOROUGH
#                            26715 non-null int64
# NEIGHBORHOOD
#                       26715 non-null object
# BUILDING CLASS CATEGORY
#            26715 non-null object
# TAX CLASS AT PRESENT
#               26715 non-null object
# BLOCK
#                              26715 non-null int64
# LOT
#                                26715 non-null int64
# EASE-MENT
#                          26715 non-null object
# BUILDING CLASS AT PRESENT
#          26715 non-null object
# ADDRESS
#                            26715 non-null object
# APARTMENT NUMBER
#                   26715 non-null object
# ZIP CODE
#                           26715 non-null int64
# RESIDENTIAL UNITS
#                  26715 non-null int64
# COMMERCIAL UNITS
#                   26715 non-null int64
# TOTAL UNITS
#                        26715 non-null int64
# LAND SQUARE FEET
# ...

# %%
df3.describe(include='all').T
# Out:
#                                   count unique  \
# BOROUGH\n                         24989    NaN
# NEIGHBORHOOD\n                    24989     39
# BUILDING CLASS CATEGORY\n         24989     43
# TAX CLASS AT PRESENT\n            24989      9
# BLOCK\n                           24989    NaN
# LOT\n                             24989    NaN
# EASE-MENT\n                       24989      1
# BUILDING CLASS AT PRESENT\n       24989    134
# ADDRESS\n                         24989  12942
# APARTMENT NUMBER\n                24989   2782
# ZIP CODE\n                        24989    NaN
# RESIDENTIAL UNITS\n               24989    NaN
# COMMERCIAL UNITS\n                24989    NaN
# TOTAL UNITS\n                     24989    NaN
# LAND SQUARE FEET\n                24989    NaN
# GROSS SQUARE FEET\n               24989    NaN
# YEAR BUILT\n                      24989    NaN
# TAX CLASS AT TIME OF SALE\n       24989    NaN
# BUILDING CLASS AT TIME OF SALE\n  24989    133
# ...

# %%
df1['BUILDING CLASS CATEGORY\n'].value_counts()
# Out:
# 13  CONDOS - ELEVATOR APARTMENTS                7995
# 10  COOPS - ELEVATOR APARTMENTS                 7532
# 45  CONDO HOTELS                                3533
# 25  LUXURY HOTELS                               1712
# 17  CONDO COOPS                                 1104
# 07  RENTALS - WALKUP APARTMENTS                  943
# 09  COOPS - WALKUP APARTMENTS                    852
# 28  COMMERCIAL CONDOS                            359
# 15  CONDOS - 2-10 UNIT RESIDENTIAL               341
# 47  CONDO NON-BUSINESS STORAGE                   268
# 08  RENTALS - ELEVATOR APARTMENTS                198
# 22  STORE BUILDINGS                              193
# 43  CONDO OFFICE BUILDINGS                       174
# 01  ONE FAMILY DWELLINGS                         173
# 46  CONDO STORE BUILDINGS                        154
# 02  TWO FAMILY DWELLINGS                         152
# 21  OFFICE BUILDINGS                             146
# 12  CONDOS - WALKUP APARTMENTS                   117
# ...

# %%
df1t=df1

# %%
df1t['bcc']=df1t['BUILDING CLASS CATEGORY\n'][0:1]

# %%
df1t.head()
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          1  ALPHABET CITY
# 1          1  ALPHABET CITY
# 2          1  ALPHABET CITY
# 3          1  ALPHABET CITY
# 4          1  ALPHABET CITY
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  02  TWO FAMILY DWELLINGS                                          1
# 1  03  THREE FAMILY DWELLINGS                                        1
# 2  04  TAX CLASS 1 CONDOS                                           1C
# 3  07  RENTALS - WALKUP APARTMENTS                                  2B
# 4  07  RENTALS - WALKUP APARTMENTS                                  2B
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0      375     41                                      S2
# 1      377     66                                      C0
# 2      399   1102                                      R6
# 3      372      6                                      C4
# ...

# %%
df3 = df3.drop(['BOROUGH\n'] , axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-136-6e93d0171e28> in <module>
# ----> 1 df3 = df3.drop(['BOROUGH\n'] , axis=0)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
df3.head(10)
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          1  ALPHABET CITY
# 1          1  ALPHABET CITY
# 2          1  ALPHABET CITY
# 3          1  ALPHABET CITY
# 4          1  ALPHABET CITY
# 5          1  ALPHABET CITY
# 6          1  ALPHABET CITY
# 7          1  ALPHABET CITY
# 8          1  ALPHABET CITY
# 9          1  ALPHABET CITY
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  01  ONE FAMILY DWELLINGS                                          1
# 1  03  THREE FAMILY DWELLINGS                                        1
# 2  03  THREE FAMILY DWELLINGS                                        1
# 3  04  TAX CLASS 1 CONDOS                                           1C
# 4  07  RENTALS - WALKUP APARTMENTS                                  2B
# 5  07  RENTALS - WALKUP APARTMENTS                                  2B
# 6  07  RENTALS - WALKUP APARTMENTS                                   2
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18642 entries, 0 to 18641
# Data columns (total 21 columns):
# BOROUGH
#                                  18642 non-null int64
# NEIGHBORHOOD
#                             18642 non-null object
# BUILDING CLASS CATEGORY
#                  18642 non-null object
# TAX CLASS AS OF FINAL ROLL 17/18         18642 non-null object
# BLOCK
#                                    18642 non-null int64
# LOT
#                                      18642 non-null int64
# EASE-MENT
#                                18642 non-null object
# BUILDING CLASS AS OF FINAL ROLL 17/18    18642 non-null object
# ADDRESS
#                                  18642 non-null object
# APARTMENT NUMBER
#                         18642 non-null object
# ZIP CODE
#                                 18642 non-null int64
# RESIDENTIAL UNITS
#                        18642 non-null int64
# COMMERCIAL UNITS
#                         18642 non-null int64
# TOTAL UNITS
# ...

# %%
len(df2['BUILDING CLASS CATEGORY\n'].value_counts())
# Out:
# 44

# %%
df1.describe(include='all').T
# Out:
#                                   count unique  \
# NEIGHBORHOOD\n                    26715     39
# BUILDING CLASS CATEGORY\n         26715     42
# TAX CLASS AT PRESENT\n            26715      9
# BLOCK\n                           26715    NaN
# LOT\n                             26715    NaN
# EASE-MENT\n                       26715      1
# BUILDING CLASS AT PRESENT\n       26715    127
# ADDRESS\n                         26715  13682
# APARTMENT NUMBER\n                26715   2797
# ZIP CODE\n                        26715    NaN
# RESIDENTIAL UNITS\n               26715    NaN
# COMMERCIAL UNITS\n                26715    NaN
# TOTAL UNITS\n                     26715    NaN
# LAND SQUARE FEET\n                26715    NaN
# GROSS SQUARE FEET\n               26715    NaN
# YEAR BUILT\n                      26715    NaN
# TAX CLASS AT TIME OF SALE\n       26715    NaN
# BUILDING CLASS AT TIME OF SALE\n  26715    125
# SALE PRICE\n                      26715    NaN
# ...

# %%
df2['BUILDING CLASS CATEGORY\n']=df2['BUILDING CLASS CATEGORY\n'].str[:2]

# %%
df2['BUILDING CLASS CATEGORY\n']=df2['BUILDING CLASS CATEGORY\n'].astype(int)

# %%
df2.head()
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  BUILDING CLASS CATEGORY\n  \
# 0          1  ALPHABET CITY                                      1
# 1          1  ALPHABET CITY                                      2
# 2          1  ALPHABET CITY                                      3
# 3          1  ALPHABET CITY                                      7
# 4          1  ALPHABET CITY                                      7
#
#   TAX CLASS AT PRESENT\n  BLOCK\n  LOT\n EASE-MENT\n  \
# 0                      1      402     42
# 1                      1      372     37
# 2                      1      377     66
# 3                     2B      372     51
# 4                      2      373     15
#
#   BUILDING CLASS AT PRESENT\n                                  ADDRESS\n  \
# 0                          S1  96 AVENUE B
# 1                          S2  17 AVENUE D
# 2                          C0  243 EAST 7TH   STREET
# 3                          C7  300 EAST 2ND   STREET
# ...

# %%
df2.describe(include='all')
# Out:
#                    NEIGHBORHOOD\n  BUILDING CLASS CATEGORY\n  \
# count                       24524               24524.000000
# unique                         40                        NaN
# top     MIDTOWN WEST                                     NaN
# freq                         4946                        NaN
# first                         NaN                        NaN
# last                          NaN                        NaN
# mean                          NaN                  17.431700
# std                           NaN                  12.176442
# min                           NaN                   1.000000
# 25%                           NaN                  10.000000
# 50%                           NaN                  13.000000
# 75%                           NaN                  17.000000
# max                           NaN                  49.000000
#
#         TAX CLASS AT PRESENT\n       BLOCK\n         LOT\n EASE-MENT\n  \
# ...

# %%
df1.head()
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          1  ALPHABET CITY
# 1          1  ALPHABET CITY
# 2          1  ALPHABET CITY
# 3          1  ALPHABET CITY
# 4          1  ALPHABET CITY
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  02  TWO FAMILY DWELLINGS                                          1
# 1  03  THREE FAMILY DWELLINGS                                        1
# 2  04  TAX CLASS 1 CONDOS                                           1C
# 3  07  RENTALS - WALKUP APARTMENTS                                  2B
# 4  07  RENTALS - WALKUP APARTMENTS                                  2B
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0      375     41                                      S2
# 1      377     66                                      C0
# 2      399   1102                                      R6
# 3      372      6                                      C4
# ...

# %%
ls1 = df1['NEIGHBORHOOD\n'].unique()
lsdict={}
a=0
for i in ls1:
    lsdict[i]=a+1
    a=a+1
lsdict 

df1['NEIGHBORHOOD\n'] = df1['NEIGHBORHOOD\n'].map(lsdict)
df1['NEIGHBORHOOD\n'].value_counts()
# Out:
# 26    6284
# 32    2269
# 33    2019
# 35    1895
# 25    1402
# 36    1132
# 2     1093
# 13     940
# 28     751
# 11     730
# 12     662
# 31     640
# 8      618
# 10     560
# 9      475
# 37     469
# 21     441
# 39     440
# 14     373
# 29     352
# 5      342
# 19     342
# 22     278
# 24     271
# 7      218
# 15     199
# 6      194
# 4      192
# 3      169
# 1      165
# 38     159
# 17     148
# 34     145
# 20      99
# 27      86
# 30      57
# 16      56
# 18      48
# 23       2
# Name: NEIGHBORHOOD\n, dtype: int64

# %%
df1['NEIGHBORHOOD\n'].value_counts()
# Out:
# MIDTOWN WEST                 6284
# UPPER EAST SIDE (59-79)      2269
# UPPER EAST SIDE (79-96)      2019
# UPPER WEST SIDE (59-79)      1895
# MIDTOWN EAST                 1402
# UPPER WEST SIDE (79-96)      1132
# CHELSEA                      1093
# HARLEM-CENTRAL                940
# MURRAY HILL                   751
# GREENWICH VILLAGE-CENTRAL     730
# GREENWICH VILLAGE-WEST        662
# TRIBECA                       640
# FINANCIAL                     618
# GRAMERCY                      560
# FLATIRON                      475
# UPPER WEST SIDE (96-116)      469
# LOWER EAST SIDE               441
# WASHINGTON HEIGHTS UPPER      440
# HARLEM-EAST                   373
# SOHO                          352
# KIPS BAY                      342
# CLINTON                       342
# MANHATTAN VALLEY              278
# MIDTOWN CBD                   271
# FASHION                       218
# HARLEM-UPPER                  199
# EAST VILLAGE                  194
# ...

# %%
df1.head()
# Out:
#    NEIGHBORHOOD\n                     BUILDING CLASS CATEGORY\n  \
# 0               1  02  TWO FAMILY DWELLINGS
# 1               1  03  THREE FAMILY DWELLINGS
# 2               1  04  TAX CLASS 1 CONDOS
# 3               1  07  RENTALS - WALKUP APARTMENTS
# 4               1  07  RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT\n  BLOCK\n  LOT\n EASE-MENT\n  \
# 0                      1      375     41
# 1                      1      377     66
# 2                     1C      399   1102
# 3                     2B      372      6
# 4                     2B      374      1
#
#   BUILDING CLASS AT PRESENT\n                                  ADDRESS\n  \
# 0                          S2  65 AVENUE D
# 1                          C0  243 EAST 7TH   STREET
# 2                          R6  238 EAST 4TH   STREET
# 3                          C4  24 AVENUE C
# 4                          C7  303 EAST 4TH STREET
#
#   APARTMENT NUMBER\n  ZIP CODE\n  \
# 0                          10009
# ...

# %%
df1['NEIGHBORHOOD\n']=df1['NEIGHBORHOOD\n'].astype(int)

# %%
df1.head()
# Out:
#    NEIGHBORHOOD\n                     BUILDING CLASS CATEGORY\n  \
# 0               1  02  TWO FAMILY DWELLINGS
# 1               1  03  THREE FAMILY DWELLINGS
# 2               1  04  TAX CLASS 1 CONDOS
# 3               1  07  RENTALS - WALKUP APARTMENTS
# 4               1  07  RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT\n  BLOCK\n  LOT\n EASE-MENT\n  \
# 0                      1      375     41
# 1                      1      377     66
# 2                     1C      399   1102
# 3                     2B      372      6
# 4                     2B      374      1
#
#   BUILDING CLASS AT PRESENT\n                                  ADDRESS\n  \
# 0                          S2  65 AVENUE D
# 1                          C0  243 EAST 7TH   STREET
# 2                          R6  238 EAST 4TH   STREET
# 3                          C4  24 AVENUE C
# 4                          C7  303 EAST 4TH STREET
#
#   APARTMENT NUMBER\n  ZIP CODE\n  \
# 0                          10009
# ...

# %%
ls2dict={}
a=0;
for i in  ls2:
    ls2dict[i]=a+1
    a=a+1

df2['NEIGHBORHOOD\n'] = df2['NEIGHBORHOOD\n'].map(ls2dict)

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24524 entries, 0 to 24523
# Data columns (total 20 columns):
# NEIGHBORHOOD
#                       0 non-null float64
# BUILDING CLASS CATEGORY
#            24524 non-null int32
# TAX CLASS AT PRESENT
#               24524 non-null object
# BLOCK
#                              24524 non-null int64
# LOT
#                                24524 non-null int64
# EASE-MENT
#                          24524 non-null object
# BUILDING CLASS AT PRESENT
#          24524 non-null object
# ADDRESS
#                            24524 non-null object
# APARTMENT NUMBER
#                   24524 non-null object
# ZIP CODE
#                           24524 non-null int64
# RESIDENTIAL UNITS
#                  24524 non-null int64
# COMMERCIAL UNITS
#                   24524 non-null int64
# TOTAL UNITS
#                        24524 non-null int64
# LAND SQUARE FEET
#                   24524 non-null int64
# GROSS SQUARE FEET
# ...

# %%
df2.head()
# Out:
#    NEIGHBORHOOD\n  BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  BLOCK\n  \
# 0             NaN                          1                      1      402
# 1             NaN                          2                      1      372
# 2             NaN                          3                      1      377
# 3             NaN                          7                     2B      372
# 4             NaN                          7                      2      373
#
#    LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0     42                                      S1
# 1     37                                      S2
# 2     66                                      C0
# 3     51                                      C7
# 4     15                                      D1
#
#                                    ADDRESS\n APARTMENT NUMBER\n  ZIP CODE\n  \
# 0  96 AVENUE B                                                        10009
# ...

# %%
df1['BUILDING CLASS CATEGORY\n']=df1['BUILDING CLASS CATEGORY\n'].str[:2]

df1['BUILDING CLASS CATEGORY\n']=df1['BUILDING CLASS CATEGORY\n'].astype(int)

# %%
# Out:
# 0         2
# 1         3
# 2         4
# 3         7
# 4         7
# 5         7
# 6         7
# 7         7
# 8         7
# 9         7
# 10        7
# 11        7
# 12        7
# 13        7
# 14        7
# 15        7
# 16        7
# 17        7
# 18        7
# 19        7
# 20        7
# 21        7
# 22        7
# 23        7
# 24        7
# 25        7
# 26        7
# 27        7
# 28        7
# 29        7
#          ..
# 26685    13
# 26686    15
# 26687    17
# 26688    17
# 26689    21
# 26690    22
# 26691    22
# 26692    22
# 26693    22
# 26694    22
# 26695    22
# 26696    29
# 26697    29
# 26698    29
# 26699    31
# 26700    31
# 26701    31
# 26702    31
# 26703    31
# 26704    31
# 26705    31
# 26706    31
# 26707    37
# 26708    44
# 26709    46
# 26710    46
# 26711    46
# 26712    46
# 26713    46
# 26714    46
# Name: BUILDING CLASS CATEGORY\n, Length: 26715, dtype: int32

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24524 entries, 0 to 24523
# Data columns (total 21 columns):
# BOROUGH
#                            24524 non-null int64
# NEIGHBORHOOD
#                       24524 non-null object
# BUILDING CLASS CATEGORY
#            24524 non-null object
# TAX CLASS AT PRESENT
#               24524 non-null object
# BLOCK
#                              24524 non-null int64
# LOT
#                                24524 non-null int64
# EASE-MENT
#                          24524 non-null object
# BUILDING CLASS AT PRESENT
#          24524 non-null object
# ADDRESS
#                            24524 non-null object
# APARTMENT NUMBER
#                   24524 non-null object
# ZIP CODE
#                           24524 non-null int64
# RESIDENTIAL UNITS
#                  24524 non-null int64
# COMMERCIAL UNITS
#                   24524 non-null int64
# TOTAL UNITS
#                        24524 non-null int64
# LAND SQUARE FEET
# ...

# %%
ls1 = df2['NEIGHBORHOOD\n'].unique()
lsdict={}
a=0
for i in ls1:
    lsdict[i]=a+1
    a=a+1
lsdict 

df2['NEIGHBORHOOD\n'] = df2['NEIGHBORHOOD\n'].map(lsdict)
df2['NEIGHBORHOOD\n'].value_counts()
# Out:
# 26    6284
# 32    2269
# 33    2019
# 35    1895
# 25    1402
# 36    1132
# 2     1093
# 13     940
# 28     751
# 11     730
# 12     662
# 31     640
# 8      618
# 10     560
# 9      475
# 37     469
# 21     441
# 39     440
# 14     373
# 29     352
# 5      342
# 19     342
# 22     278
# 24     271
# 7      218
# 15     199
# 6      194
# 4      192
# 3      169
# 1      165
# 38     159
# 17     148
# 34     145
# 20      99
# 27      86
# 30      57
# 16      56
# 18      48
# 23       2
# Name: NEIGHBORHOOD\n, dtype: int64

# %%
df1['BUILDING CLASS CATEGORY\n']=df1['BUILDING CLASS CATEGORY\n'].str[:2]
df1['BUILDING CLASS CATEGORY\n']=df1['BUILDING CLASS CATEGORY\n'].astype(int)
